# %% [markdown]
# # 03 Conservative switch-point identification
#
# The operational definition identifies adjacent `eng -> spa` and `spa -> eng` transitions from corpus-provided language annotations inside one recording, speaker and utterance. Any other label resets the sequence. This is a rule-based corpus measure, not an automatic language-identification classifier.

# %% [markdown]
# ## 1. Read the synthetic language sequence
#
# Synthetic questionnaire fields are attached here only because the switch function also produces participant-ready recording summaries.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))
from bangor_miami.tokens import iter_tsv_tokens
from bangor_miami.switches import conservative_switches
tokens = [{**row, 'questionnaire_id': row['speaker'], 'education_level': 3, 'education_group': 'Middle'} for row in iter_tsv_tokens(ROOT / 'data/sample/tsvs')]
[(row['utterance_id'], row['surface'], row['langid']) for row in tokens]

# %% [markdown]
# ## 2. Detect transitions
#
# The event table preserves direction and both token surfaces, allowing every count to be audited.

# %%
events, recording_rates = conservative_switches(tokens)
events

# %% [markdown]
# ## 3. Standardise by valid exposure
#
# Only `eng` and `spa` tokens enter the denominator. Labels such as `999` are boundaries, not missing English or Spanish words.

# %%
recording_rates

# %% [markdown]
# ## Verified private-corpus result
#
# The strict participant cohort contained 195,864 valid English/Spanish tokens and 2,980 conservative within-utterance transitions, a pooled rate of 15.21 per 1,000 valid tokens. This definition is intentionally narrower than every linguistic use of the term code-switching.
