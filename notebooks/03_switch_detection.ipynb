# %% [markdown]
# # 03 Conservative switch detection
#
# Only adjacent `eng -> spa` and `spa -> eng` transitions inside one utterance are counted. Other labels reset the sequence.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))
from bangor_miami.tokens import iter_tsv_tokens
from bangor_miami.switches import conservative_switches
tokens = [{**row, 'questionnaire_id': row['speaker'], 'education_level': 3, 'education_group': 'Middle'} for row in iter_tsv_tokens(ROOT / 'data/sample/tsvs')]
events, recording_rates = conservative_switches(tokens)
events, recording_rates

# %% [markdown]
# This is an operational definition. It is intentionally narrower than all linguistic uses of the term code-switching.
