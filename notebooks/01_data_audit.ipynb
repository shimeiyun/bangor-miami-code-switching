# %% [markdown]
# # 01 Data audit
#
# This notebook inspects the redistributable synthetic CHAT and TSV files. The same functions are used for the private corpus run.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))
from bangor_miami.chat import chat_inventory
from bangor_miami.tokens import iter_tsv_tokens
chat_rows = chat_inventory(ROOT / 'data/sample/chats')
tokens = list(iter_tsv_tokens(ROOT / 'data/sample/tsvs'))
{'chat_speaker_rows': len(chat_rows), 'token_rows': len(tokens), 'first_chat_row': chat_rows[0]}

# %% [markdown]
# The audit is a research output: it records what was read or excluded instead of silently changing the corpus.
